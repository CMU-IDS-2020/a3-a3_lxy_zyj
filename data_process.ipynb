# %%
import pandas as pd

url = '../2018.csv'
df = pd.read_csv(url)
# df = df.dropna()
# df = df.loc[df['FL_DATE'].str.contains('2018-02-0')]
df = df.loc[df['ORIGIN'].str.contains('SFO')]

print(df.columns)
df = df.drop('Unnamed: 27', 1)
df = df.drop('CANCELLATION_CODE', 1)
print(df)
df.to_csv("2018-sfo.csv")
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Unnamed: 27'],
#       dtype='object')
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 21       2018-01-01         UA               2405    SFO  IAH           530
# 23       2018-01-01         UA               2403    SFO  HNL          1927
# 53       2018-01-01         UA               2163    SFO  RNO          1048
# 54       2018-01-01         UA               2162    SFO  EUG          2013
# 60       2018-01-01         UA               2156    SFO  CLE          2240
# ...

# %%
import pandas as pd

url = '../2018.csv'
df = pd.read_csv(url)
# df = df.dropna()
df = df.loc[df['FL_DATE'].str.contains('2018-02-01')]
# df = df.loc[df['ORIGIN'].str.contains('SFO')]

df = df.drop('Unnamed: 27', 1)
df = df.drop('CANCELLATION_CODE', 1)
df = df.fillna(0)
print(df.columns)
print(df)
df.to_csv("2018-02-01.csv")
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST',
#        'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME',
#        'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY'],
#       dtype='object')
#            FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 570118  2018-02-01         F9               1104    LAS  MIA            40
# 570119  2018-02-01         F9                408    LAX  DEN            59
# 570120  2018-02-01         F9               1456    LAS  ATL            15
# 570121  2018-02-01         F9               1680    LAS  MCO            30
# 570122  2018-02-01         F9                680    DEN  MCO            50
# ...            ...        ...                ...    ...  ...           ...
# ...

# %%
ls
# Out:
# 2018-01.csv         LICENSE             flight.py           streamlit_app.py
# 2018-02.csv         README.md           requirements.txt    writeup.md
# 2018-las.csv        business.csv        review.csv
# 2018-sfo.csv        data_process.ipynb  screenshot.png

# %%
ls -l
# Out:
# total 421712
# -rw-r--r--  1 lixuanyi  staff  72880070 Oct 20 00:22 2018-01.csv
# -rw-r--r--  1 lixuanyi  staff  21088015 Oct 20 11:36 2018-02.csv
# -rw-r--r--  1 lixuanyi  staff  20745253 Oct 20 00:51 2018-las.csv
# -rw-r--r--  1 lixuanyi  staff  22775085 Oct 20 00:53 2018-sfo.csv
# -rw-r--r--  1 lixuanyi  staff      1534 Oct 19 17:15 LICENSE
# -rw-r--r--  1 lixuanyi  staff      1743 Oct 19 17:15 README.md
# -rw-------@ 1 lixuanyi  staff  29916314 Oct 19 22:23 business.csv
# -rw-r--r--  1 lixuanyi  staff     11973 Oct 20 11:38 data_process.ipynb
# -rw-r--r--  1 lixuanyi  staff      2814 Oct 20 11:37 flight.py
# -rw-r--r--  1 lixuanyi  staff        24 Oct 19 17:15 requirements.txt
# -rw-------@ 1 lixuanyi  staff  33915593 Oct 19 22:23 review.csv
# -rw-r--r--  1 lixuanyi  staff   1082606 Oct 19 17:15 screenshot.png
# -rw-r--r--  1 lixuanyi  staff      2172 Oct 19 20:53 streamlit_app.py
# -rw-r--r--  1 lixuanyi  staff       970 Oct 19 17:15 writeup.md
